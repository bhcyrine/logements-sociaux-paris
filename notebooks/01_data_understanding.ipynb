# %% [markdown]
# # 01 — Data Understanding
#
# Ce notebook explore le dataset brut des logements sociaux financés à Paris avant tout nettoyage, pour identifier sa structure, sa qualité, et les points d'attention à traiter dans `02_data_cleaning.ipynb`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
df = pd.read_csv("../data/raw/logements-sociaux-finances-a-paris.csv", sep=';')
df.head()
# Out:
#   id_livraison           adresse_programme code_postal  ville  annee  \
# 0      2000011      16-20 RUE DES MEUNIERS       75012  Paris   2001
# 1      2000035         25 RUE DES ANNELETS       75019  Paris   2001
# 2      2000044  LOT D1B - 86 RUE DES HAIES       75020  Paris   2001
# 3      2000048            31 QUAI DE VALMY       75010  Paris   2001
# 4      2000062          19 RUE DES PLANTES       75014  Paris   2001
#
#               bs  nb_logmt_total  nb_plai  nb_plus  nb_pluscd  nb_pls  \
# 0       RES.URB.              62        0       62          0       0
# 1           RIVP              18       10        8          0       0
# 2           RIVP               6        0        6          0       0
# 3  PARIS HABITAT              28        0       22          0       6
# 4  PARIS HABITAT              38        0       15          0      23
#
#                       mode_real  commentaires  arrdt   nature_programme  \
# 0  acquisition conventionnement           NaN     12  logement familial
# 1    acquisition réhabilitation           NaN     19  logement familial
# 2    acquisition réhabilitation           NaN     20  logement familial
# 3  acquisition conventionnement           NaN     10  logement familial
# 4  acquisition conventionnement           NaN     14  logement familial
#
#    coord_x_l93   coord_y_l93  \
# 0  655823.1529  6.859495e+06
# 1  655225.8330  6.864433e+06
# 2  656258.4385  6.861828e+06
# 3  653551.4260  6.863384e+06
# 4  650356.4410  6.859151e+06
#
#                                            geo_shape  \
# 0  {"coordinates": [2.398175442412243, 48.8339981...
# 1  {"coordinates": [2.3895183752327043, 48.878361...
# 2  {"coordinates": [2.403865260493333, 48.8550036...
# 3  {"coordinates": [2.366804047083707, 48.8688074...
# 4  {"coordinates": [2.3237456731730535, 48.830499...
#
#                             geo_point_2d
# 0   48.83399817959342, 2.398175442412243
# 1   48.8783619998301, 2.3895183752327043
# 2   48.85500366971155, 2.403865260493333
# 3   48.86880747974437, 2.366804047083707
# 4  48.83049983027532, 2.3237456731730535

# %%
df[['mode_real','nature_programme','nb_logmt_total','bs','nb_plai']].head(20)
# Out:
#                        mode_real     nature_programme  nb_logmt_total  \
# 0   acquisition conventionnement    logement familial              62
# 1     acquisition réhabilitation    logement familial              18
# 2     acquisition réhabilitation    logement familial               6
# 3   acquisition conventionnement    logement familial              28
# 4   acquisition conventionnement    logement familial              38
# 5             construction neuve    logement familial               8
# 6             construction neuve    logement familial              18
# 7     acquisition réhabilitation    logement familial               7
# 8     acquisition réhabilitation    logement familial              19
# 9   acquisition conventionnement    logement familial              16
# 10    acquisition réhabilitation    logement familial              13
# 11    acquisition réhabilitation    logement familial               5
# 12    acquisition réhabilitation    logement familial              45
# 13            construction neuve    logement familial              14
# 14            construction neuve    logement familial               5
# 15    acquisition réhabilitation    logement familial               4
# 16  acquisition conventionnement    logement familial              83
# 17    acquisition réhabilitation    logement familial              14
# 18  acquisition conventionnement    logement familial              27
# 19            construction neuve  résidence étudiante              21
#
#                    bs  nb_plai
# 0            RES.URB.        0
# 1                RIVP       10
# 2                RIVP        0
# 3       PARIS HABITAT        0
# 4       PARIS HABITAT        0
# 5       PARIS HABITAT        0
# 6       PARIS HABITAT       18
# 7        ELOGIE SIEMP        0
# 8        ELOGIE SIEMP        0
# 9   1001 VIES HABITAT        5
# 10  1001 VIES HABITAT        0
# 11           ALLIANCE        5
# 12      PARIS HABITAT       11
# 13      PARIS HABITAT        0
# 14      PARIS HABITAT        0
# 15      PARIS HABITAT        0
# 16             (vide)        0
# 17       ELOGIE SIEMP        0
# 18      PARIS HABITAT        6
# 19      PARIS HABITAT        0

# %% [markdown]
# ## 2. Vue d'ensemble

# %%
print("Nombre de lignes :", df.shape[0])
print("Nombre de colonnes :", df.shape[1])
# Out:
# Nombre de lignes : 4174
# Nombre de colonnes : 19

# %%
df.columns.to_list()
# Out:
# ['id_livraison',
#  'adresse_programme',
#  'code_postal',
#  'ville',
#  'annee',
#  'bs',
#  'nb_logmt_total',
#  'nb_plai',
#  'nb_plus',
#  'nb_pluscd',
#  'nb_pls',
#  'mode_real',
#  'commentaires',
#  'arrdt',
#  'nature_programme',
#  'coord_x_l93',
#  'coord_y_l93',
#  'geo_shape',
#  'geo_point_2d']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4174 entries, 0 to 4173
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_livraison       4174 non-null   str
#  1   adresse_programme  4174 non-null   str
#  2   code_postal        4174 non-null   str
#  3   ville              4174 non-null   str
#  4   annee              4174 non-null   int64
#  5   bs                 4174 non-null   str
#  6   nb_logmt_total     4174 non-null   int64
#  7   nb_plai            4174 non-null   int64
#  8   nb_plus            4174 non-null   int64
#  9   nb_pluscd          4174 non-null   int64
#  10  nb_pls             4174 non-null   int64
#  11  mode_real          4174 non-null   str
#  12  commentaires       0 non-null      float64
#  13  arrdt              4174 non-null   int64
#  14  nature_programme   4174 non-null   str
#  15  coord_x_l93        4174 non-null   float64
#  16  coord_y_l93        4174 non-null   float64
#  17  geo_shape          4174 non-null   str
#  18  geo_point_2d       4174 non-null   str
# dtypes: float64(3), int64(7), str(9)
# memory usage: 1.4 MB

# %%
df.dtypes
# Out:
# id_livraison             str
# adresse_programme        str
# code_postal              str
# ville                    str
# annee                  int64
# bs                       str
# nb_logmt_total         int64
# nb_plai                int64
# nb_plus                int64
# nb_pluscd              int64
# nb_pls                 int64
# mode_real                str
# commentaires         float64
# arrdt                  int64
# nature_programme         str
# coord_x_l93          float64
# coord_y_l93          float64
# geo_shape                str
# geo_point_2d             str
# dtype: object

# %% [markdown]
# ## 3. Qualité des données
#
# Lignes dupliquées, valeurs manquantes déclarées, et utilisation mémoire.

# %%
print(f"lignes dupliquées :{df.duplicated().sum()}")
# Out:
# lignes dupliquées :0

# %%
print("\nValeurs manquantes par colonne :")
missing = df.isnull().sum()
missing_pct = (missing / len(df) * 100).round(2)
print(pd.DataFrame({"missing_count": missing, "missing_pct": missing_pct}))
# Out:
# Valeurs manquantes par colonne :
#                    missing_count  missing_pct
# id_livraison                   0          0.0
# adresse_programme              0          0.0
# code_postal                    0          0.0
# ville                          0          0.0
# annee                          0          0.0
# bs                             0          0.0
# nb_logmt_total                 0          0.0
# nb_plai                        0          0.0
# nb_plus                        0          0.0
# nb_pluscd                      0          0.0
# nb_pls                         0          0.0
# mode_real                      0          0.0
# commentaires                4174        100.0
# arrdt                          0          0.0
# nature_programme               0          0.0
# coord_x_l93                    0          0.0
# coord_y_l93                    0          0.0
# geo_shape                      0          0.0
# geo_point_2d                   0          0.0

# %% [markdown]
# ## 4. Variables catégorielles
#
# Résumé général puis inspection détaillée des deux variables clés pour l'hypothèse (`mode_real`, `nature_programme`), ainsi que `bs` (pour repérer les valeurs manquantes déguisées).

# %%
print("\nRésumé des variables catégorielles :")
print(df.describe(include=["object", "category"]))
# Out:
# Résumé des variables catégorielles :
#        id_livraison adresse_programme code_postal  ville            bs  \
# count          4174              4174        4174   4174          4174
# unique         4141              3705          21      1            66
# top         2002559    36, RUE SIBUET       75018  Paris  ELOGIE SIEMP
# freq              3                 7         520   4174          1098
#
#                  mode_real   nature_programme  \
# count                 4174               4174
# unique                   3                 13
# top     construction neuve  logement familial
# freq                  1638               3551
#
#                                                 geo_shape  \
# count                                                4174
# unique                                               3492
# top     {"coordinates": [2.40247300337046, 48.84379734...
# freq                                                   12
#
#                                 geo_point_2d
# count                                   4174
# unique                                  3492
# top     48.843797349838404, 2.40247300337046
# freq                                      12
# C:\Users\cyrin\AppData\Local\Temp\ipykernel_28112\1956021498.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   print(df.describe(include=["object", "category"]))

# %%
print("Nombre de valeurs uniques par colonne :")
print(df.nunique())
# Out:
# Nombre de valeurs uniques par colonne :
# id_livraison         4141
# adresse_programme    3705
# code_postal            21
# ville                   1
# annee                  24
# bs                     66
# nb_logmt_total        243
# nb_plai               143
# nb_plus               167
# nb_pluscd              24
# nb_pls                147
# mode_real               3
# commentaires            0
# arrdt                  20
# nature_programme       13
# coord_x_l93          3490
# coord_y_l93          3491
# geo_shape            3492
# geo_point_2d         3492
# dtype: int64

# %% [markdown]
# ### `mode_real` — variable explicative de l'hypothèse

# %%
print(df['mode_real'].value_counts(dropna=False))
# Out:
# mode_real
# construction neuve              1638
# acquisition réhabilitation      1594
# acquisition conventionnement     942
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(6, 6))
counts = df['mode_real'].value_counts()
colors = ['#D85A30', '#1D9E75', '#378ADD']
ax.pie(counts, labels=counts.index, autopct='%1.1f%%', colors=colors, startangle=90)
ax.set_title("Répartition des programmes par mode de réalisation")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### `nature_programme` — facteur de confusion potentiel

# %%
print(df['nature_programme'].value_counts(dropna=False))
# Out:
# nature_programme
# logement familial                                                                    3551
# résidence étudiante                                                                   173
# foyer pour jeunes travailleurs ou résidence pour jeunes actifs                        114
# maison relais                                                                          84
# résidence sociale pour démunis                                                         81
# foyer de travailleurs migrants                                                         36
# résidence sociale issue du plan de traitement des foyers de travailleurs migrants      33
# foyer pour personnes handicapées                                                       32
# établissement d'hébergement pour personnes âgées dépendantes                           26
# centre d'hébergement d'urgence                                                         26
# résidence pour personnes âgées                                                         10
# centre d'hébergement et de réinsertion sociale                                          7
# centre d'hébergement et de stabilisation                                                1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8, 7))
counts = df['nature_programme'].value_counts()

# Regrouper les catégories < 2% dans "Autres" pour éviter le chevauchement des labels
threshold = 0.02
main_counts = counts[counts / counts.sum() >= threshold]
autres = counts[counts / counts.sum() < threshold].sum()
if autres > 0:
    main_counts = pd.concat([main_counts, pd.Series({'Autres': autres})])

wedges, texts, autotexts = ax.pie(
    main_counts, autopct='%1.1f%%', startangle=90,
    textprops={'fontsize': 9}, pctdistance=0.8
)

ax.legend(wedges, main_counts.index, title="Nature du programme",
          loc='center left', bbox_to_anchor=(1, 0.5), fontsize=9)
ax.set_title("Répartition des programmes par nature")
plt.savefig("../outputs/Répartition_des_programmes_par_nature", dpi=150)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### `bs`

# %%
print(df['bs'].value_counts(dropna=False))
# Out:
# bs
# ELOGIE SIEMP        1098
# PARIS HABITAT       1021
# RIVP                 783
# AXIMO                147
# IMM 3F               123
#                     ...
# ASS.MAR.TH             1
# SCI KEREN              1
# SCCV  129 DAVOUT       1
# CIUP                   1
# HOMYA                  1
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# ## 5. Variables numériques
#
# Statistiques descriptives, plages de valeurs, et corrélations.

# %%
print("Statistiques descriptives (colonnes numériques)")
df.describe()
# Out:
# Statistiques descriptives (colonnes numériques)
#              annee  nb_logmt_total      nb_plai      nb_plus    nb_pluscd  \
# count  4174.000000     4174.000000  4174.000000  4174.000000  4174.000000
# mean   2012.272640       30.317202     8.293244    12.512698     0.174892
# std       6.107193       62.877886    25.114113    33.987187     2.557760
# min    2001.000000       -8.000000    -8.000000    -1.000000     0.000000
# 25%    2008.000000        4.000000     0.000000     0.000000     0.000000
# 50%    2012.000000       13.000000     1.000000     3.000000     0.000000
# 75%    2017.000000       30.000000     6.000000    11.000000     0.000000
# max    2024.000000     1332.000000   400.000000   799.000000    92.000000
#
#             nb_pls  commentaires        arrdt    coord_x_l93   coord_y_l93
# count  4174.000000           0.0  4174.000000    4174.000000  4.174000e+03
# mean      9.336368           NaN    13.882846  652446.840649  6.862554e+06
# std      29.690293           NaN     4.955583    2668.942840  2.469549e+03
# min       0.000000           NaN     1.000000  645313.119000  6.857636e+06
# 25%       0.000000           NaN    11.000000  650667.110000  6.860459e+06
# 50%       0.000000           NaN    15.000000  652626.340500  6.862616e+06
# 75%       6.000000           NaN    18.000000  654546.157900  6.864759e+06
# max     533.000000           NaN    20.000000  657018.241000  6.867035e+06

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
for col in numeric_cols:
    print(f"{col}: min={df[col].min()}, max={df[col].max()}, mean={df[col].mean():.2f}")
# Out:
# annee: min=2001, max=2024, mean=2012.27
# nb_logmt_total: min=-8, max=1332, mean=30.32
# nb_plai: min=-8, max=400, mean=8.29
# nb_plus: min=-1, max=799, mean=12.51
# nb_pluscd: min=0, max=92, mean=0.17
# nb_pls: min=0, max=533, mean=9.34
# commentaires: min=nan, max=nan, mean=nan
# arrdt: min=1, max=20, mean=13.88
# coord_x_l93: min=645313.119, max=657018.241, mean=652446.84
# coord_y_l93: min=6857636.1173, max=6867035.1139, mean=6862553.57

# %%
print("Matrice de corrélation :")
print(df[numeric_cols].corr())
# Out:
# Matrice de corrélation :
#                    annee  nb_logmt_total   nb_plai   nb_plus  nb_pluscd  \
# annee           1.000000        0.014854  0.048402 -0.030948  -0.039503
# nb_logmt_total  0.014854        1.000000  0.574810  0.801997   0.024814
# nb_plai         0.048402        0.574810  1.000000  0.229557  -0.012430
# nb_plus        -0.030948        0.801997  0.229557  1.000000  -0.020783
# nb_pluscd      -0.039503        0.024814 -0.012430 -0.020783   1.000000
# nb_pls          0.029346        0.711376  0.109751  0.361354   0.000708
# commentaires         NaN             NaN       NaN       NaN        NaN
# arrdt           0.001919        0.067869  0.024863  0.012929   0.020390
# coord_x_l93    -0.020527        0.010338 -0.016097 -0.023908  -0.011441
# coord_y_l93    -0.070529       -0.063309 -0.025253 -0.063928   0.050132
#
#                   nb_pls  commentaires     arrdt  coord_x_l93  coord_y_l93
# annee           0.029346           NaN  0.001919    -0.020527    -0.070529
# nb_logmt_total  0.711376           NaN  0.067869     0.010338    -0.063309
# nb_plai         0.109751           NaN  0.024863    -0.016097    -0.025253
# nb_plus         0.361354           NaN  0.012929    -0.023908    -0.063928
# nb_pluscd       0.000708           NaN  0.020390    -0.011441     0.050132
# nb_pls          1.000000           NaN  0.106145     0.063863    -0.043855
# commentaires         NaN           NaN       NaN          NaN          NaN
# arrdt           0.106145           NaN  1.000000     0.097654     0.288305
# coord_x_l93     0.063863           NaN  0.097654     1.000000     0.105282
# coord_y_l93    -0.043855           NaN  0.288305     0.105282     1.000000

# %% [markdown]
# ## 6. Investigation — valeurs négatives
#
# Quelques lignes présentent des comptages négatifs, ce qui est impossible pour un nombre de logements.

# %%
neg_cols = ['nb_logmt_total', 'nb_plai', 'nb_plus', 'nb_pluscd', 'nb_pls']
neg_mask = (df[neg_cols] < 0).any(axis=1)
print(f"{neg_mask.sum()} lignes avec au moins un nombre négatif\n")
neg_rows = df.loc[neg_mask, ['id_livraison', 'adresse_programme', 'annee', 'bs',
                              'mode_real', 'nb_logmt_total', 'nb_plai', 'nb_plus',
                              'nb_pluscd', 'nb_pls']]
print(neg_rows)
# Out:
# 2 lignes avec au moins un nombre négatif
#
#      id_livraison                              adresse_programme  annee  \
# 2528      2000587  56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET   2010
# 3457      2000900       16-22, RUE FERNAND LEGER (FOYER MURIERS)   2010
#
#                 bs                   mode_real  nb_logmt_total  nb_plai  \
# 2528  ELOGIE SIEMP          construction neuve               5        6
# 3457       COALLIA  acquisition réhabilitation              -8       -8
#
#       nb_plus  nb_pluscd  nb_pls
# 2528       -1          0       0
# 3457        0          0       0

# %%
print("Par mode_real:")
print(neg_rows["mode_real"].value_counts())
print("\nPar bs:")
print(neg_rows["bs"].value_counts())
print("\nPar annee:")
print(neg_rows["annee"].value_counts().sort_index())
# Out:
# Par mode_real:
# mode_real
# construction neuve            1
# acquisition réhabilitation    1
# Name: count, dtype: int64
#
# Par bs:
# bs
# ELOGIE SIEMP    1
# COALLIA         1
# Name: count, dtype: int64
#
# Par annee:
# annee
# 2010    2
# Name: count, dtype: int64

# %%
check = neg_rows.copy()
check['sum_categories'] = check[['nb_plai', 'nb_plus', 'nb_pluscd', 'nb_pls']].sum(axis=1)
check['matches_total'] = check['sum_categories'] == check['nb_logmt_total']
print("Vérification de cohérence (total == somme des sous-catégories) :")
print(check[['id_livraison', 'nb_logmt_total', 'sum_categories', 'matches_total']])
# Out:
# Vérification de cohérence (total == somme des sous-catégories) :
#      id_livraison  nb_logmt_total  sum_categories  matches_total
# 2528      2000587               5               5           True
# 3457      2000900              -8              -8           True

# %% [markdown]
# ## 7. Investigation — `id_livraison` dupliqués
#
# Vérifier si les identifiants qui apparaissent plusieurs fois sont de vrais doublons ou des tranches/phases légitimes du même programme.

# %%
dupe_ids = df[df.duplicated('id_livraison', keep=False)].sort_values('id_livraison')
print(f"{dupe_ids['id_livraison'].nunique()} identifiants distincts apparaissent plus d'une fois "
      f"({len(dupe_ids)} lignes au total)\n")
print(dupe_ids[['id_livraison', 'adresse_programme', 'annee', 'mode_real',
                 'nb_logmt_total']].to_string())
# Out:
# 32 identifiants distincts apparaissent plus d'une fois (65 lignes au total)
#
#      id_livraison                                                     adresse_programme  annee                     mode_real  nb_logmt_total
# 1656      2000403                                                        25, RUE MORAND   2004    acquisition réhabilitation              29
# 1963      2000403                                                        25, RUE MORAND   2004            construction neuve               9
# 1972      2000587                         56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET   2005    acquisition réhabilitation              15
# 2528      2000587                         56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET   2010            construction neuve               5
# 1560      2000735                                       161-161BIS RUE DE LA CONVENTION   2006    acquisition réhabilitation               5
# 2052      2000735                                       161-161BIS RUE DE LA CONVENTION   2006    acquisition réhabilitation              50
# 910       2000749                      6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE   2010            construction neuve               1
# 3522      2000749                      6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE   2006            construction neuve              16
# 696       2000750                      6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE   2010            construction neuve               4
# 4004      2000750                      6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE   2006            construction neuve              10
# 1041      2000767                                   84, AVENUE DU DOCTEUR ARNOLD NETTER   2007            construction neuve              32
# 3087      2000767                                   84, AVENUE DU DOCTEUR ARNOLD NETTER   2007            construction neuve              24
# 3457      2000900                              16-22, RUE FERNAND LEGER (FOYER MURIERS)   2010    acquisition réhabilitation              -8
# 409       2003725                 9 QUAI SAINT BERNARD 8BIS RUE CUVIER (BARRE CASSAN F)   2024    acquisition réhabilitation              16
# 2645      2003725                    9 QUAI SAINT BERNARD CUVIER (BARRE CASSAN JUSSIEU)   2020            construction neuve             565
# 3665      2003752                                                 124, RUE DES PYRENEES   2020            construction neuve              21
# 3694      2003752                                                 124, RUE DES PYRENEES   2024            construction neuve               4
# 2331      2003780                                                  125 RUE SAINT MARTIN   2024    acquisition réhabilitation               1
# 3335      2003780                                                  125 RUE SAINT MARTIN   2021    acquisition réhabilitation               1
# 3048      2003789                                                      7 RUE AIME MOROT   2024    acquisition réhabilitation               1
# 3667      2003789                                                      7 RUE AIME MOROT   2021    acquisition réhabilitation               2
# 1197      2003849            SECTEUR HEBERT LOT G 54 RUE DE L'EVANGILE et 20 RUE CUGNOT   2024            construction neuve               7
# 2738      2003849            SECTEUR HEBERT LOT G 54 RUE DE L'EVANGILE et 20 RUE CUGNOT   2021            construction neuve              61
# 3049      2003970                                                      8 RUE DE LABORDE   2024    acquisition réhabilitation               6
# 3231      2003970                                                      8 RUE DE LABORDE   2022    acquisition réhabilitation              12
# 2745      2004056                                                        4 RUE MERCOEUR   2022            construction neuve              41
# 3922      2004056                                                        4 RUE MERCOEUR   2024            construction neuve               1
# 1312      2004067                                             10 RUE DU DOCTEUR LAURENT   2024    acquisition réhabilitation               1
# 2224      2004067                                             10 RUE DU DOCTEUR LAURENT   2023    acquisition réhabilitation               4
# 511       2004147                                  CASERNE CHALVIDAN 45-57  BD EXELMANS   2023    acquisition réhabilitation               4
# 4166      2004147                                  CASERNE CHALVIDAN 45-57  BD EXELMANS   2023    acquisition réhabilitation               9
# 196       2004216                                                        18 RUE SURCOUF   2024            construction neuve               4
# 3695      2004216                                                        18 RUE SURCOUF   2024    acquisition réhabilitation              11

# %%
# Les lignes dupliquées partagent-elles la même adresse et la même année (vrai doublon)
# ou diffèrent-elles (livraison distincte / phases différentes) ?
dupe_ids['same_addr_year'] = dupe_ids.duplicated(
    subset=['id_livraison', 'adresse_programme', 'annee'], keep=False
)
print("Lignes où adresse + année sont identiques pour le même id_livraison "
      "(probablement de vrais doublons) :")
print(dupe_ids[dupe_ids['same_addr_year']])

print("\nLignes où l'adresse ou l'année diffère (probablement des livraisons distinctes légitimes) :")
print(dupe_ids[~dupe_ids['same_addr_year']])
# Out:
# Lignes où adresse + année sont identiques pour le même id_livraison (probablement de vrais doublons) :
#      id_livraison                     adresse_programme code_postal  ville  \
# 1656      2000403                        25, RUE MORAND       75011  Paris
# 1963      2000403                        25, RUE MORAND       75011  Paris
# 1560      2000735       161-161BIS RUE DE LA CONVENTION       75015  Paris
# 2052      2000735       161-161BIS RUE DE LA CONVENTION       75015  Paris
# 1041      2000767   84, AVENUE DU DOCTEUR ARNOLD NETTER       75012  Paris
# 3087      2000767   84, AVENUE DU DOCTEUR ARNOLD NETTER       75012  Paris
# 1005      2003476            32, RUE DU GENERAL GUILHEM       75011  Paris
# 3895      2003476            32, RUE DU GENERAL GUILHEM       75011  Paris
# 511       2004147  CASERNE CHALVIDAN 45-57  BD EXELMANS       75016  Paris
# 4166      2004147  CASERNE CHALVIDAN 45-57  BD EXELMANS       75016  Paris
# 196       2004216                        18 RUE SURCOUF       75007  Paris
# 3695      2004216                        18 RUE SURCOUF       75007  Paris
#
#       annee             bs  nb_logmt_total  nb_plai  nb_plus  nb_pluscd  \
# 1656   2004         (vide)              29       29        0          0
# 1963   2004         (vide)               9        9        0          0
# 1560   2006   ELOGIE SIEMP               5        5        0          0
# 2052   2006   ELOGIE SIEMP              50       50        0          0
# 1041   2007        COALLIA              32       32        0          0
# 3087   2007        COALLIA              24       24        0          0
# 1005   2019          AXIMO               1        1        0          0
# 3895   2019          AXIMO               1        0        1          0
# 511    2023      HAB.CONF.               4        4        0          0
# 4166   2023      HAB.CONF.               9        5        3          0
# 196    2024  PARIS HABITAT               4        2        2          0
# 3695   2024  PARIS HABITAT              11        7        4          0
#
#       nb_pls                     mode_real  commentaires  arrdt  \
# 1656       0    acquisition réhabilitation           NaN     11
# 1963       0            construction neuve           NaN     11
# 1560       0    acquisition réhabilitation           NaN     15
# 2052       0    acquisition réhabilitation           NaN     15
# 1041       0            construction neuve           NaN     12
# 3087       0            construction neuve           NaN     12
# 1005       0    acquisition réhabilitation           NaN     11
# 3895       0  acquisition conventionnement           NaN     11
# 511        0    acquisition réhabilitation           NaN     16
# 4166       1    acquisition réhabilitation           NaN     16
# 196        0            construction neuve           NaN      7
# 3695       0    acquisition réhabilitation           NaN      7
#
#                                        nature_programme  coord_x_l93  \
# 1656                     résidence sociale pour démunis  654199.4889
# 1963                     résidence sociale pour démunis  654199.4889
# 1560                     résidence sociale pour démunis  648140.6969
# 2052  résidence sociale issue du plan de traitement ...  648140.6969
# 1041  résidence sociale issue du plan de traitement ...  656427.5080
# 3087                     résidence sociale pour démunis  656427.5080
# 1005                                  logement familial  654436.3489
# 3895                                  logement familial  654436.3489
# 511                                       maison relais  645821.1120
# 4166                                  logement familial  645821.1120
# 196                                   logement familial  649333.4260
# 3695                                  logement familial  649333.4260
#
#        coord_y_l93                                          geo_shape  \
# 1656  6.863460e+06  {"coordinates": [2.375629943357381, 48.8695423...
# 1963  6.863460e+06  {"coordinates": [2.375629943357381, 48.8695423...
# 1560  6.860082e+06  {"coordinates": [2.293450430354241, 48.8387008...
# 2052  6.860082e+06  {"coordinates": [2.293450430354241, 48.8387008...
# 1041  6.860884e+06  {"coordinates": [2.40626606627324, 48.84652724...
# 3087  6.860884e+06  {"coordinates": [2.40626606627324, 48.84652724...
# 1005  6.862691e+06  {"coordinates": [2.3789412304605166, 48.862643...
# 3895  6.862691e+06  {"coordinates": [2.3789412304605166, 48.862643...
# 511   6.860477e+06  {"coordinates": [2.2617990953885383, 48.842060...
# 4166  6.860477e+06  {"coordinates": [2.2617990953885383, 48.842060...
# 196   6.862524e+06  {"coordinates": [2.309408754220773, 48.8607588...
# 3695  6.862524e+06  {"coordinates": [2.309408754220773, 48.8607588...
#
#                                geo_point_2d  same_addr_year
# 1656   48.86954232974593, 2.375629943357381            True
# 1963   48.86954232974593, 2.375629943357381            True
# 1560   48.83870085017224, 2.293450430354241            True
# 2052   48.83870085017224, 2.293450430354241            True
# 1041    48.84652724974555, 2.40626606627324            True
# 3087    48.84652724974555, 2.40626606627324            True
# 1005  48.86264339979978, 2.3789412304605166            True
# 3895  48.86264339979978, 2.3789412304605166            True
# 511   48.84206067960417, 2.2617990953885383            True
# 4166  48.84206067960417, 2.2617990953885383            True
# 196    48.86075880023908, 2.309408754220773            True
# 3695   48.86075880023908, 2.309408754220773            True
#
# Lignes où l'adresse ou l'année diffère (probablement des livraisons distinctes légitimes) :
#      id_livraison                                  adresse_programme  \
# 1972      2000587      56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET
# 2528      2000587      56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET
# 910       2000749   6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE
# 3522      2000749   6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE
# 696       2000750   6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE
# 4004      2000750   6-8, RUE DES THERMOPYLES 13-15, RUE DE PLAISANCE
# 3457      2000900           16-22, RUE FERNAND LEGER (FOYER MURIERS)
# 3528      2000900           16-22, RUE FERNAND LEGER (FOYER MURIERS)
# 240       2000964         144-160 RUE DE LA TOMBE ISSOIRE BD JOURDAN
# 911       2000964         144-160 RUE DE LA TOMBE ISSOIRE BD JOURDAN
# 1029      2001519                                   65 BD KELLERMANN
# 2525      2001519                                   65 BD KELLERMANN
# 294       2001767                                   73 BD KELLERMANN
# 2330      2001767                                   73 BD KELLERMANN
# 3241      2001768                                      3 RUE THOMIRE
# 4045      2001768                                      3 RUE THOMIRE
# 408       2002080                                  75, BD KELLERMANN
# 1103      2002080                                  75, BD KELLERMANN
# 721       2002196                                  5-7, RUE DU SAHEL
# 1311      2002196                                 1 RUE PAUL CRAMPEL
# 195       2002258                                   62, RUE REGNAULT
# 727       2002258                                   62, RUE REGNAULT
# 1121      2002559                           128-138, BOULEVARD MURAT
# 2642      2002559      128-138 BD MURAT 16 AVENUE DU GENERAL CLAVERY
# 3902      2002559      128-138 BD MURAT 14 AVENUE DU GENERAL CLAVERY
# 515       2002726                                  6, RUE AIME MOROT
# 2981      2002726                                  6, RUE AIME MOROT
# 1125      2002727                                  63, BD KELLERMANN
# 3355      2002727                                  63, BD KELLERMANN
# 3283      2002792                      1-11, RUE DE L'ABBE ROUSSELOT
# 3903      2002792  1-11, RUE DE L'ABBE ROUSSELOT 4 SQUARE DE LA M...
# 782       2003243  21, AVENUE CLAUDE VELLEFAUX\n7-9 AVENUE SAMBRE...
# 1178      2003243  21, AVENUE CLAUDE VELLEFAUX\n7-9 AVENUE SAMBRE...
# 3899     18             résidence étudiante  652491.5880  6.866920e+06
# 409       5             résidence étudiante  652929.1930  6.861104e+06
# 2645      5             résidence étudiante  652929.1930  6.861104e+06
# 3665     20               logement familial  656231.6810  6.862183e+06
# 3694     20               logement familial  656231.6810  6.862183e+06
# 2331      4               logement familial  652398.2429  6.862509e+06
# 3335      4               logement familial  652398.2429  6.862509e+06
# 3048     13               logement familial  652272.8980  6.857974e+06
# 3667     13               logement familial  652272.8980  6.857974e+06
# 1197     18               logement familial  653461.1579  6.866172e+06
# 2738     18               logement familial  653461.1579  6.866172e+06
# 3049      8               logement familial  650262.4260  6.864192e+06
# 3231      8               logement familial  650262.4260  6.864192e+06
# 2745     11             résidence étudiante  654739.9660  6.862050e+06
# 3922     11             résidence étudiante  654739.9660  6.862050e+06
# 1312     13               logement familial  652747.6600  6.858513e+06
# 2224     13               logement familial  652747.6600  6.858513e+06
#
#                                               geo_shape  \
# 1972  {"coordinates": [2.385961611610783, 48.8563578...
# 2528  {"coordinates": [2.385961611610783, 48.8563578...
# 910   {"coordinates": [2.3196694534666418, 48.832503...
# 3522  {"coordinates": [2.3196694534666418, 48.832503...
# 696   {"coordinates": [2.3196694534666418, 48.832503...
# 4004  {"coordinates": [2.3196694534666418, 48.832503...
# 3457  {"coordinates": [2.3903089586380464, 48.863982...
# 3528  {"coordinates": [2.3903089586380464, 48.863982...
# 240   {"coordinates": [2.3291048866355895, 48.822628...
# 911   {"coordinates": [2.3291048866355895, 48.822628...
# 1029  {"coordinates": [2.3500033296464617, 48.820547...
# 2525  {"coordinates": [2.3500033296464617, 48.820547...
# 294   {"coordinates": [2.3489582466719203, 48.820243...
# 2330  {"coordinates": [2.3489582466719203, 48.820243...
# 3241  {"coordinates": [2.348462362022473, 48.8197372...
# 4045  {"coordinates": [2.348462362022473, 48.8197372...
# 408   {"coordinates": [2.3486786014010326, 48.820114...
# 1103  {"coordinates": [2.3486786014010326, 48.820114...
# 721   {"coordinates": [2.4016194064618985, 48.841211...
# 1311  {"coordinates": [2.405763249262014, 48.8410200...
# 195   {"coordinates": [2.3736864726323152, 48.823907...
# 727   {"coordinates": [2.3736864726323152, 48.823907...
# 1121  {"coordinates": [2.2600913693610165, 48.836846...
# 2642  {"coordinates": [2.2600913693610165, 48.836846...
# 3902  {"coordinates": [2.2600913693610165, 48.836846...
# 515   {"coordinates": [2.3496838889917857, 48.820024...
# 2981  {"coordinates": [2.3496838889917857, 48.820024...
# 1125  {"coordinates": [2.3505837671993004, 48.820705...
# 3355  {"coordinates": [2.3505837671993004, 48.820705...
# 3283  {"coordinates": [2.30096463518962, 48.88901417...
# 3903  {"coordinates": [2.30096463518962, 48.88901417...
# 782   {"coordinates": [2.3701447824790396, 48.875656...
# 1178  {"coordinates": [2.3701447824790396, 48.875656...
# 1179  {"coordinates": [2.3775106810527404, 48.823061...
# 3894  {"coordinates": [2.3775106810527404, 48.823061...
# 3242  {"coordinates": [2.3519611233827695, 48.900532...
# 2331   48.86085786961917, 2.3511822986126827           False
# 3335   48.86085786961917, 2.3511822986126827           False
# 3048     48.8200624401359, 2.349982772255713           False
# 3667     48.8200624401359, 2.349982772255713           False
# 1197  48.893874139882385, 2.3652680244059177           False
# 2738  48.893874139882385, 2.3652680244059177           False
# 3049   48.87583180968929, 2.3218752524105986           False
# 3231   48.87583180968929, 2.3218752524105986           False
# 2745  48.856894639741014, 2.3831478581171095           False
# 3922  48.856894639741014, 2.3831478581171095           False
# 1312   48.824946340027054, 2.356388632340047           False
# 2224   48.824946340027054, 2.356388632340047           False

# %% [markdown]
# ## 8. Vérification — cohérence de `mode_real` au sein d'un même `id_livraison`
#
# Un même programme (`id_livraison`) devrait avoir un seul `mode_real` ; sinon, l'agrégation par mode serait faussée.

# %%
incoherent = df.groupby('id_livraison')['mode_real'].nunique()
n_incoherent = (incoherent > 1).sum()
print(f"Programmes avec mode_real incohérent entre leurs lignes : {n_incoherent}")

ids_incoherents = incoherent[incoherent > 1].index
if n_incoherent > 0:
    print(df[df['id_livraison'].isin(ids_incoherents)]
          [['id_livraison', 'adresse_programme', 'annee', 'mode_real']])
# Out:
# Programmes avec mode_real incohérent entre leurs lignes : 7
#      id_livraison                                  adresse_programme  annee  \
# 196       2004216                                     18 RUE SURCOUF   2024
# 409       2003725  9 QUAI SAINT BERNARD 8BIS RUE CUVIER (BARRE CA...   2024
# 721       2002196                                  5-7, RUE DU SAHEL   2012
# 1005      2003476                         32, RUE DU GENERAL GUILHEM   2019
# 1311      2002196                                 1 RUE PAUL CRAMPEL   2024
# 1656      2000403                                     25, RUE MORAND   2004
# 1963      2000403                                     25, RUE MORAND   2004
# 1972      2000587      56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET   2005
# 2528      2000587      56-58, RUE LEON FROT 3, RUE CARRIERE MAINGUET   2010
# 2645      2003725  9 QUAI SAINT BERNARD CUVIER (BARRE CASSAN JUSS...   2020
# 3457      2000900           16-22, RUE FERNAND LEGER (FOYER MURIERS)   2010
# 3528      2000900           16-22, RUE FERNAND LEGER (FOYER MURIERS)   2007
# 3695      2004216                                     18 RUE SURCOUF   2024
# 3895      2003476                         32, RUE DU GENERAL GUILHEM   2019
#
#                          mode_real
# 196             construction neuve
# 409     acquisition réhabilitation
# 721             construction neuve
# 1005    acquisition réhabilitation
# 1311    acquisition réhabilitation
# 1656    acquisition réhabilitation
# 1963            construction neuve
# 1972    acquisition réhabilitation
# 2528            construction neuve
# 2645            construction neuve
# 3457    acquisition réhabilitation
# 3528            construction neuve
# 3695    acquisition réhabilitation
# 3895  acquisition conventionnement

# %%
# Test plus robuste : comparer le début de l'adresse (moins sensible aux petites
# variations de texte) plutôt que l'égalité stricte
for id_ in ids_incoherents:
    sub = df[df['id_livraison'] == id_]
    adresses = sub['adresse_programme'].unique()
    prefixes = set(a.strip().upper()[:15] for a in adresses)
    same_prefix = len(prefixes) == 1
    flag = "OK (adresse similaire)" if same_prefix else "SUSPECT (adresses vraiment différentes)"
    print(f"id_livraison {id_} — {flag}")
    if not same_prefix:
        for a in adresses:
            print(f"   -> {a}")
# Out:
# id_livraison 2000403 — OK (adresse similaire)
# id_livraison 2000587 — OK (adresse similaire)
# id_livraison 2000900 — OK (adresse similaire)
# id_livraison 2002196 — SUSPECT (adresses vraiment différentes)
#    -> 5-7, RUE DU SAHEL
#    -> 1 RUE PAUL CRAMPEL
# id_livraison 2003476 — OK (adresse similaire)
# id_livraison 2003725 — OK (adresse similaire)
# id_livraison 2004216 — OK (adresse similaire)

# %% [markdown]
# ## 9. Investigation — outlier `nb_logmt_total`
#
# Vérifier si les plus grosses valeurs (jusqu'à 1332 logements) sont plausibles ou des erreurs de saisie.

# %%
top_programs = df.sort_values('nb_logmt_total', ascending=False).head(10)
print(top_programs[['id_livraison', 'adresse_programme', 'annee', 'bs',
                     'mode_real', 'nb_logmt_total']])
# Out:
#      id_livraison                                  adresse_programme  annee  \
# 1175      2003676                                 PORTE DE MONTREUIL   2019
# 3869      2002949           92-94-98, BD PONIATOWSKI 2-4, RUE DUBOIS   2016
# 3283      2002792                      1-11, RUE DE L'ABBE ROUSSELOT   2015
# 2175      2002793                          1-11, SQUARE DU THIMERAIS   2015
# 3894      2003460                     15 AVENUE DE LA PORTE DE VITRY   2018
# 3303      2003251                       174 ET 180-188, RUE LECOURBE   2017
# 1121      2002559                           128-138, BOULEVARD MURAT   2014
# 3288      2002963        54-68, 70-72 ET 109-111, BOULEVARD SERURIER   2016
# 2645      2003725  9 QUAI SAINT BERNARD CUVIER (BARRE CASSAN JUSS...   2020
# 759       2002794                           1-8, SQUARE DU THIMERAIS   2015
#
#                  bs                     mode_real  nb_logmt_total
# 1175  PARIS HABITAT  acquisition conventionnement            1332
# 3869  PARIS HABITAT  acquisition conventionnement            1136
# 3283  PARIS HABITAT  acquisition conventionnement            1019
# 2175  PARIS HABITAT  acquisition conventionnement             849
# 3894  PARIS HABITAT  acquisition conventionnement             833
# 3303  PARIS HABITAT  acquisition conventionnement             760
# 1121  PARIS HABITAT  acquisition conventionnement             634
# 3288  PARIS HABITAT  acquisition conventionnement             595
# 2645           RIVP            construction neuve             565
# 759   PARIS HABITAT  acquisition conventionnement             529

# %%
print(f"99e percentile : {df['nb_logmt_total'].quantile(0.99):.0f}")
print(f"95e percentile : {df['nb_logmt_total'].quantile(0.95):.0f}")
print(f"Maximum : {df['nb_logmt_total'].max()}")

# Vérification manuelle (ex. recherche en ligne de l'adresse) pour contrôler la
# cohérence de l'échelle — de grands programmes parisiens de 1000+ logements existent
# Out:
# 99e percentile : 277
# 95e percentile : 115
# Maximum : 1332

# %% [markdown]
# ## 10. `nature_programme` × `mode_real` — facteur de confusion
#
# Vérifier si `nature_programme` influence la distribution de `mode_real`, ce qui justifierait de restreindre l'analyse principale au logement familial.

# %%
print(df['nature_programme'].value_counts())

print("\nnature_programme x mode_real (pourcentage par ligne) :")
ct = pd.crosstab(df['nature_programme'], df['mode_real'], normalize='index')
print((ct * 100).round(1))
# Out:
# nature_programme
# logement familial                                                                    3551
# résidence étudiante                                                                   173
# foyer pour jeunes travailleurs ou résidence pour jeunes actifs                        114
# maison relais                                                                          84
# résidence sociale pour démunis                                                         81
# foyer de travailleurs migrants                                                         36
# résidence sociale issue du plan de traitement des foyers de travailleurs migrants      33
# foyer pour personnes handicapées                                                       32
# établissement d'hébergement pour personnes âgées dépendantes                           26
# centre d'hébergement d'urgence                                                         26
# résidence pour personnes âgées                                                         10
# centre d'hébergement et de réinsertion sociale                                          7
# centre d'hébergement et de stabilisation                                                1
# Name: count, dtype: int64
#
# nature_programme x mode_real (pourcentage par ligne) :
# mode_real                                           acquisition conventionnement  \
# nature_programme
# centre d'hébergement d'urgence                                               7.7
# centre d'hébergement et de réinsertion sociale                               0.0
# centre d'hébergement et de stabilisation                                     0.0
# foyer de travailleurs migrants                                               0.0
# foyer pour jeunes travailleurs ou résidence pou...                           0.0
# foyer pour personnes handicapées                                             0.0
# logement familial                                                           26.4
# maison relais                                                                1.2
# résidence pour personnes âgées                                               0.0
# résidence sociale issue du plan de traitement d...                           0.0
# résidence sociale pour démunis                                               1.2
# résidence étudiante                                                          1.2
# établissement d'hébergement pour personnes âgée...                           0.0
#
# mode_real                                           acquisition réhabilitation  \
# nature_programme
# centre d'hébergement d'urgence                                            15.4
# centre d'hébergement et de réinsertion sociale                            28.6
# centre d'hébergement et de stabilisation                                 100.0
# foyer de travailleurs migrants                                            16.7
# foyer pour jeunes travailleurs ou résidence pou...                        29.8
# foyer pour personnes handicapées                                           6.2
# logement familial                                                         40.6
# maison relais                                                             32.1
# résidence pour personnes âgées                                            10.0
# résidence sociale issue du plan de traitement d...                        21.2
# résidence sociale pour démunis                                            43.2
# résidence étudiante                                                       17.9
# établissement d'hébergement pour personnes âgée...                         7.7
#
# mode_real                                           construction neuve
# nature_programme
# centre d'hébergement d'urgence                                    76.9
# centre d'hébergement et de réinsertion sociale                    71.4
# centre d'hébergement et de stabilisation                           0.0
# foyer de travailleurs migrants                                    83.3
# foyer pour jeunes travailleurs ou résidence pou...                70.2
# foyer pour personnes handicapées                                  93.8
# logement familial                                                 33.0
# maison relais                                                     66.7
# résidence pour personnes âgées                                    90.0
# résidence sociale issue du plan de traitement d...                78.8
# résidence sociale pour démunis                                    55.6
# résidence étudiante                                               80.9
# établissement d'hébergement pour personnes âgée...                92.3

# %%
print(df.groupby('mode_real')[['nb_plai', 'nb_plus', 'nb_pluscd', 'nb_pls']]
        .agg(['sum', 'mean', 'min']))
# Out:
#                              nb_plai                nb_plus                 \
#                                  sum       mean min     sum       mean min
# mode_real
# acquisition conventionnement    7464   7.923567   0   20582  21.849257   0
# acquisition réhabilitation      8840   5.545797  -8   10162   6.375157   0
# construction neuve             18312  11.179487   0   21484  13.115995  -1
#
#                              nb_pluscd               nb_pls
#                                    sum      mean min    sum       mean min
# mode_real
# acquisition conventionnement         0  0.000000   0  18597  19.742038   0
# acquisition réhabilitation          58  0.036386   0   5200   3.262233   0
# construction neuve                 672  0.410256   0  15173   9.263126   0

# %% [markdown]
# ## 11. Vérification — cohérence `nb_logmt_total` vs sous-catégories
#
# `nb_logmt_total` doit correspondre exactement à la somme de `nb_plai` + `nb_plus` + `nb_pluscd` + `nb_pls`.

# %%
df['sum_categories'] = df[['nb_plai', 'nb_plus', 'nb_pluscd', 'nb_pls']].sum(axis=1)
mismatch = df[df['sum_categories'] != df['nb_logmt_total']]
print(f"Lignes où le total ne correspond pas à la somme des sous-catégories : {len(mismatch)}")

if len(mismatch) > 0:
    print(mismatch[['id_livraison', 'adresse_programme', 'annee', 'mode_real',
                     'nb_logmt_total', 'sum_categories']])
# Out:
# Lignes où le total ne correspond pas à la somme des sous-catégories : 0

# %% [markdown]
# ## le total exact de logements

# %%
print(df['nb_logmt_total'].sum())
# Out:
# 126544

# %% [markdown]
# ## Conclusions — Data Understanding
#
# - **Négatifs** (`nb_plai`/`nb_plus`/`nb_logmt_total` < 0) : quelques lignes isolées,
#   probablement des corrections de déclarations antérieures. Impact négligeable
#   (2 lignes / 4174). Décision : exclues du dataset nettoyé.
#
# - **id_livraison dupliqués** : NE SONT PAS des doublons. Ils représentent des tranches
#   de financement ou des phases de livraison distinctes d'un même programme.
#   Décision : conservées telles quelles, id_livraison n'est pas une clé unique par ligne.
#
# - **id_livraison avec mode_real incohérent entre ses lignes** : 7 cas détectés sur le
#   dataset brut (10 lignes). Test de similarité d'adresse (préfixe normalisé) :
#   6 cas sont des tranches/phases légitimes du même programme (même adresse, à des
#   variations d'écriture près). 1 cas (id_livraison 2002196) présente deux adresses
#   réellement différentes (5-7 RUE DU SAHEL vs 1 RUE PAUL CRAMPEL, années 2012/2024),
#   suggérant une réutilisation de l'identifiant plutôt qu'un même programme.
#   Comme l'analyse se fait au niveau ligne (chaque ligne porte son propre mode_real
#   et ses comptes de financement), ceci n'affecte pas l'agrégation par mode_real.
#   Aucune action de nettoyage nécessaire ; documenté pour ne pas traiter id_livraison
#   comme identifiant de projet fiable.
#
# - **bs = "(vide)"** : placeholder de valeur manquante (109 lignes), non utilisé dans
#   l'analyse principale. Pas d'action nécessaire.
#
# - **Outlier nb_logmt_total = 1332** : légitime, cohérent avec les gros programmes
#   d'acquisition conventionnement (rachat de parc immobilier existant, ex. Porte de
#   Montreuil). Conservé.
#
# - **nature_programme fortement corrélé à mode_real** (ex : résidences étudiantes
#   81% en acquisition réhabilitation, EHPAD 92% en acquisition conventionnement) :
#   facteur de confusion potentiel pour l'analyse principale. Décision : analyse
#   centrée sur `nature_programme == "logement familial"` (3551 programmes), avec
#   vérification de robustesse sur le dataset complet.
#
# - **Cohérence nb_logmt_total / sous-catégories** : vérifié que `nb_logmt_total`
#   correspond exactement à la somme de `nb_plai` + `nb_plus` + `nb_pluscd` + `nb_pls`
#   sur 100% des lignes (0 écart).
